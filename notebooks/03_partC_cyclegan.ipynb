# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f2027, #203a43, #2c5364); padding: 28px; border-radius: 24px; text-align: center; color: #f2f5f7; box-shadow: 0 8px 20px rgba(0,0,0,0.12);">
#   <h1 style="font-size: 42px; margin-bottom: 8px;">🔄 Unpaired Translation 🔄</h1>
#   <h2 style="font-size: 24px; margin-top: 0;">03 · Part C — CycleGAN (ExDark ↔ LoLI-Street)</h2>
#   <p style="font-size: 18px;">No paired supervision: can restoration be learned from unmatched domains?</p>
# </div>

# %% [markdown]
# ### Imports

# %%
import sys
from pathlib import Path
import torch
REPO = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(REPO / "src"))
from cyclegan.generators import ResNetGenerator
from cyclegan.discriminators import FakePool, PatchDiscriminator
from cyclegan.train_cyclegan import UnpairedDataset
dev = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", dev)

# %% [markdown]
# <div style="background: linear-gradient(135deg, #74c69d, #48cae4); padding: 26px; border-radius: 22px; margin-top: 28px; border: 4px solid #2d6a4f; box-shadow: 0 8px 22px rgba(0, 0, 0, 0.18); color: #081c15;">
#   <h1 style="color: #081c15; background-color: rgba(255,255,255,0.65); padding: 12px 16px; border-radius: 14px; margin-top: 0;">🔁 Generators, discriminators, cycle loss</h1>
#   <p style="font-size: 17px; line-height: 1.7; color: #133f30; font-weight: 500;">
#     ResNet-9 generators (11.4M params, InstanceNorm, tanh), 70x70 PatchGAN critics,
#     fake-image pool, cycle weight 10, identity weight 5. Smoke-tested (shapes + 1 mini-epoch).
#   </p>
# </div>

# %% [markdown]
# ### Unpaired domains

# %%
ds = UnpairedDataset(size=256, subset=64)
a, b = ds[0]
print("domain A (ExDark):", tuple(a.shape), "domain B (LoLI high):", tuple(b.shape), "pairs:", len(ds))

# %% [markdown]
# <div style="background: linear-gradient(135deg, #f093fb, #f5576c); padding: 26px; border-radius: 22px; margin-top: 28px; border: 4px solid #a01040; box-shadow: 0 8px 22px rgba(0, 0, 0, 0.18); color: #fff0f5;">
#   <h1 style="color: #fff0f5; background-color: rgba(255,255,255,0.15); padding: 12px 16px; border-radius: 14px; margin-top: 0;">🏋️ Training (TODO)</h1>
#   <p style="font-size: 17px; line-height: 1.7; color: #ffe0e8;">
#     Full training starts after the pix2pix final pass frees the GPU. Eval is sample grids +
#     YOLO mAP on ExDark only (no ground truth exists there by construction).
#   </p>
# </div>
